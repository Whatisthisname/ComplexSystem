# %% [markdown]
# # Team 20 Disinformation spreaders
# ## Title: Modelling the spread of disinformation in online social networks.

# %% [markdown]
# **Team members:**
# Oskar Bosgraaf, Boyu Chen, Alicja Dorobis (13896687),  Theo Würtzen.

# %% [markdown]
# ## Project to-do
# 1. Each person cleans up their code
# 2. Each make a file with the description of their AI use
# 3. Below we add theory and explanation of the methods we coded

# %% [markdown]
# ## Abstract

# %% [markdown]
# Disinformation, misinformation and fake news are becoming an increasingly pressing issue, particularly due to today’s nature of information sharing, which has been critically changed by the proliferation of social media and the advent of quick content generated by Artificial Intelligence. The increased spread of false content leads to the polarisation of political views, which can have a profound impact on democratic processes as well as increase the risk of political instability and reduce social cohesion.
#
# This project aimed to investigate the sudden transition from neutrality or consensus to bimodal polarisation to draw conclusions about disinformation spread in social networks. This research aimed to analyse these mechanisms by applying the framework developed by Evangelatos et al. in a paper titled “Modeling Disinformation Spread in Social Networks: Phase Transitions and Mean-Field Analysis” and secondly by expanding this model through the introduction of a propaganda event.

# %% [markdown]
# # Introduction

# %% [markdown]
# * which paper we are replicating and why it is useful
# * summarise the main findings of the paper
# * why we are adding a propaganda event - need a source for this
# *

# %% [markdown]
# Paper - static external field
# Our addition - dynamic external field - representing a propaganda event
#
# **RQ:** How do external influences, such as propaganda events, alter the ciritcal threshold at which a social network transitions to a different belief state?
#
# **H1:** The critical threshold required for disinformation adoption
# * doing just one topology e.g. Erdos Renyi and comparing the 4 different parameter sets that are based on heatmap plot
# * sth about ciritcal thereshold
# * Theo had an idea for another plot as well
#
# **H2:** The Scale-Free networks are less resilient to propaganda events than Small-World or Erdos-Renyi.
#
# * Scale free had highest magnetization in the paper, thus we expect they will not recover as well from the propaganda
# * comparison of all 3 topologies for the same set of parameters
# * analysis of the peak, difference between pre and post propagand, the slope,
#
#
# Resilience - combination of lower peak and small difference in the average magnetization before the peak and after the peak
#
# **H3:** Increase in memory coefficient leads to a decrease in adoption of disinformation after a propaganda event and increased resilience of the network.
#
# * varying memory coeffcient (influnced fraction of neighbours)
# * heatmap with inv. temp 1,5 for one topology - Erdos?

# %% [markdown]
# # Theory

# %% [markdown]
# ### Network Topology (theory)

# %% [markdown]
# 1. Erdos-Renyi networks are
# 2. Scale free
# 3. Small world - add papers for each

# %% [markdown]
# * sth about the propaganda - the dynamic field?
# * Critical thereshold + explain phase transitions
# * Bifurcations

# %% [markdown]
# # Methodology
# The framework utilises a dynamic mean-field framework with a Three-State Potts Model to simulate disinformation adoption on a social network graph. This approach divides the population into three belief categories: adoption, rejection, and neutrality of the disinformed belief. This approach also incorporated a heterogeneous coupling strength, meaning the coupling strength accounts for hubs which exert stronger pulling forces, thus closer mirroring the dynamics of real-world scale-free networks. Furthermore, this study also closely simulates human psychology through memory effects, where a memory coefficient allows an individual’s prior beliefs to influence their current state. Finally, Monte Carlo simulations will be conducted, which will allow for the observation of transient dynamics.
# The original study will be extended by adding temporal dynamics through a decay function applied to the memory effects function. While the initial model utilises memory effect to reinforce a belief, the extended model will argue that information overload leads to the degeneration of social bonds. Namely, if a node is faced with too much conflicting information, it can experience numbness and overstimulation, where the disoriented individual is less responsive to their peer’s influence. To address the research question, this new model will be compared to the baseline model introduced by Evangelatos et al.. This comparison will aim to investigate how the critical threshold and giant component formation are influenced by the introduction of the new memory fatigue function.
#
#
# * all methods, how we set up paramters

# %% [markdown]
# #### Network Topology
#
# This project analysed the impact of network topology on the mangetization. for this three topologies were analysed: interaction networks Erdős–Rényi, Scale-Free (Barabási–Albert ) and Small-World (Watts–Strogatz). The code for the implementation of those topologies was created with the ue of GPT4 (for detailed usage see appendix).
#
# Comparable Small-World, Scale-Free, and Erdős-Rényi graphs were created by matching network size and average degree. Thus, to ensure structural differences stem from topology rather than density.

# %% [markdown]
# * Voronoi diagrams
# * clustering

# %% [markdown]
# # Results and discussion

# %% [markdown]
# ### Side by side voronoi diagrams
#
# <div style="display: flex; gap: 1px;">
#     <img src="results/erdos_heatmap.png" alt="Erdos Renyi Heatmap" width="300"/>
#     <img src="results/scale_free_heatmap.png" alt="Scale Free Heatmap" width="300"/>
#     <img src="results/small_world_heatmap.png" alt="Small World Heatmap" width="300"/>
# </div>

# %% [markdown]
# ### Impact of network typology on magnetization
#
# ## Erdos-Renyi
#
# ![alt text](results/erdos_heatmap.png)
# ![alt text](results/Erdos_Renyi_high_noise.png)
# ![alt text](results/Erdos_Renyi_recovery.png)
# ![alt text](results/Erdos_Renyi_tipping.png)
# * this shows the system as a tipping point
# ![alt text](results/Erdos_Renyi_vulnerable.png)
# * this is post transition
# * 10 runs for the graphs
#
#
# ![Descriptive Alt Text](erdos_renyi_individual.gif)
# ![Descriptive Alt Text](erdos_renyi_lambda_sweep.gif)
# * 100 frames, with linear step over lambda $\in \[ 0.0, 0.35 \]$
# * 20 runs for the gifs
#
#
# Analysis:
# * We fixed the beta and analysed the performance of 10 trajectories for the graphs.
# * this shows the phase transistion

# %% [markdown]
# ## Scale-Free
# ![alt text](results/scale_free_heatmap.png)
# ![alt text](results/Scale_Free_high_noise.png)
# ![alt text](results/Scale_Free_recovery.png)
# ![alt text](results/Scale_Free_tipping.png)
# ![alt text](results/Scale_Free_vulnerable.png)
#
# ## Small-World
# ![alt text](results/small_world_heatmap.png)
# ![alt text](results/Small_World_high_noise.png)
# ![alt text](results/Small_World_recovery.png)
# ![alt text](results/Small_World_tipping.png)
# ![alt text](results/Small_World_vulnerable.png)
#
# Analysis: Since we already proved this is a phase transistion we created a parameter sweep aslo for the other topolgies and analysed the tipping points and correspodning parameters. This allows us to answer hypothesis 2 - as expected, the tipping point for scale-free is at a lower lambda: 0.15 vs ...
# meaning that the scale free networks are less resilient to propaganda. this is insigtul and can inform antipropaganda campaigns etc. etc.
#
#
# ### Comparison of mean
# ![alt text](results/Network_topology.png)

# %% [markdown]
# # Memory coefficient impact on criticality
#
# ![alt text](results/memory_vs_population_fraction.png)
#
# Need to answer hypothesis 3 - take the values of beta for citical points from erdos and see what value of it is now, if at the same beta we get a critical point or not. sth like this
# Analysis:

# %% [markdown]
# # Connectivity
# Add
#
# Analysis:

# %% [markdown]
# ## Bifurcation of steady states
#
# ![alt text](results/bifurcation_of_steady_states.png)
#
#
# Analysis:

# %% [markdown]
# # Conclusions

# %% [markdown]
# ### Network typology
#
#
# ? this research can help identify which networks are more resistant to disinformation propaganda. (maybe)

# %% [markdown]
# ### References
# Evangelatos, S., Veroni, E., Efthymiou, V., & Nikolopoulos, C. (2025). Modeling Disinformation Spread in Social Networks: Phase Transitions and Mean-Field Analysis. ACM Trans. Web, 19(4), 46:1-46:24. https://doi.org/10.1145/3747287
